# %% [markdown]
# # ChainLink Price Prediction 2021

# %% [markdown]
# ## 1. Data Preparation

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as web
import seaborn as sns
import math
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, classification_report,accuracy_score, mean_absolute_error
from sklearn.model_selection import train_test_split

from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.callbacks import EarlyStopping
from keras.layers import Bidirectional, Input, GRU
from keras.models import Sequential,Model

# %%
df = pd.read_csv('data/coin_ChainLink.csv')

#spliting 'Date' column to 'date' and 'time'
df['Date'] = pd.to_datetime(df['Date'])
df['date'] = df['Date'].dt.date
df['time'] = df['Date'].dt.time

#drop non-relevant columns
df.drop(['SNo','Name','Symbol','Date','time'], axis=1, inplace=True,errors='ignore')
#set date as new index
df.set_index('date',inplace=True)

# %%
plt.figure(figsize=(16,8))
plt.title('Litecoin Close Price History')
plt.plot(df['Close'])

# %% [markdown]
# # Using 1 input for LSTM model

# %% [markdown]
# ## 2.Data Preprocessing

# %%
df = df.loc[pd.to_datetime(df.index) > pd.to_datetime('2017-06-01'),:]

# %%
column_indices = {name: i for i, name in enumerate(df.columns)}

n = len(df)
train_df = df[0:int(n*0.8)]
val_df = df[int(n*0.8):int(n*0.95)]
test_df = df[int(n*0.95):]

num_features = df.shape[1]

# %%
#Create a new dataframe with only close column
#data = df.filter(['Close'])
#convert to a numpy array
#dataset = data.values

#get the number of rows to train the model on
#train_idx = math.ceil(len(dataset) * .8)

#train_idx

# %%
def line_plot2(line1, line2,label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

def line_plot3(line1, line2,line3, label1=None, label2=None,label3=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.plot(line3, label=label3, linewidth=lw)
    ax.set_ylabel('price [USD]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)


line_plot3(line1 = train_df.filter(['Close']), 
          line2 = val_df.filter(['Close']),
          line3 = test_df.filter(['Close']), label1='training',label2='val',label3= 'test', title='')

# %% [markdown]
# ### 2.1 Data Normalization

# %%
def scale_func(df):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(df)
    scaled_data = pd.DataFrame(scaled_data,index=df.index, columns=df.columns)
    return scaled_data, scaler

scaled_train_df, scaler  = scale_func(train_df) 
scaled_val_df = pd.DataFrame(scaler.transform(val_df),index=val_df.index,columns=val_df.columns)
scaled_test_df = pd.DataFrame(scaler.transform(test_df),index=test_df.index,columns=test_df.columns)

# %%
#create the training data set
def generate_input(df, window, target):
    #create the scaled training data set
    #Split the data into x_train and y_train data sets
    x_train = []
    y_train = []
    for i in range(window, len(df)):
        x_train.append(df.iloc[i-window:i, :][target])
        y_train.append(df.iloc[i,:,][target])
    x_train, y_train = np.array(x_train), np.array(y_train)
    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
    return x_train, y_train

# %%
x_train, y_train = generate_input(scaled_train_df,15, "Close")
#convert x_train and y_train to numpy arrays
x_val, y_val = generate_input(scaled_val_df,15, "Close")
x_test, y_test = generate_input(scaled_test_df,15, "Close")

print("Training set:",x_train.shape)
print("Validation set:",x_val.shape)
print("Test set:",x_test.shape)
# Out:
# Training set: (989, 15, 1)
# Validation set: (174, 15, 1)
# Test set: (48, 15, 1)

# %%
def model_base_build(input_shape):
    #build the lstm model
    model = Sequential()
    model.add(LSTM(50, return_sequences=True, input_shape = input_shape))
    model.add(LSTM(50, return_sequences=False, dropout=0.5, recurrent_dropout=0.4))
    model.add(Dense(1))
    model.add(Activation('linear'))
    #compile the model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def model_class_build(input_shape):
    #build the lstm model
    model = Sequential()
    #### Adding the first LSTM layer and some Dropout regularisation
    model.add(LSTM(units = 50, return_sequences = True, input_shape = input_shape))
    model.add(Dropout(0.2))
    #### Adding a second LSTM layer and some Dropout regularisation
    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))
    #### Adding a third LSTM layer and some Dropout regularisation
    model.add(LSTM(units = 50, return_sequences = True))
    model.add(Dropout(0.2))
    #### Adding a fourth LSTM layer and some Dropout regularisation
    model.add(LSTM(units = 50))
    model.add(Dropout(0.2))
    #### Adding the output layer
    model.add(Dense(units = 1))
    model.add(Activation('linear'))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def model_GRU_build(input_shape):
    model = Sequential()
    # Input layer
    model.add(GRU(100, return_sequences = True, input_shape = input_shape))
    model.add(Dropout(0.2)) 
    # Hidden layer
    model.add(GRU(100)) 
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.add(Activation('linear'))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def accuracy_forecast(target_val ,prediction_val):   
    bi_targ = np.sign(target_val.rolling(window=2).apply(lambda x: x.iloc[1] - x.iloc[0]))[1:].values
    bi_pred = np.sign(prediction_val.rolling(window=2).apply(lambda x: x.iloc[1] - x.iloc[0]))[1:].values
    return accuracy_score(bi_targ,bi_pred)

# %%
model = model_GRU_build(input_shape= (x_train.shape[1],x_train.shape[2]))

# %%
#train the model
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 4s 49ms/step - loss: 0.0487 - val_loss: 0.0646
# Epoch 2/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0761
# Epoch 3/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.0881
# Epoch 4/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0024 - val_loss: 0.1171
# Epoch 5/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0019 - val_loss: 0.1009
# Epoch 6/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.1240
# Epoch 7/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.1081
# Epoch 8/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0615
# Epoch 9/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.1021
# Epoch 10/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0571
# Epoch 11/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0893
# Epoch 12/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0018 - val_loss: 0.0773
# Epoch 13/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0733
# Epoch 14/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0869
# Epoch 15/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.1108
# Epoch 16/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0021 - val_loss: 0.1302
# Epoch 17/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.1284
# Epoch 18/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.1359
# Epoch 19/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.1568
# Epoch 20/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.2380
# Epoch 21/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0825
# Epoch 22/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.1087
# Epoch 23/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0838
# Epoch 24/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.1645
# Epoch 25/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.1190
# Epoch 26/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0961
# Epoch 27/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1215
# Epoch 28/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1438
# Epoch 29/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.1041
# Epoch 30/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0776
# Epoch 31/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.1818
# Epoch 32/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.1648
# Epoch 33/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.1363
# Epoch 34/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1505
# Epoch 35/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0986
# Epoch 36/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 0.0792
# Epoch 37/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.1634
# Epoch 38/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.1612
# Epoch 39/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1383
# Epoch 40/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.1445
# Epoch 41/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.1286
# Epoch 42/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.1390
# Epoch 43/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.1577
# Epoch 44/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.1094
# Epoch 45/100
# 31/31 [==============================] - 0s 11ms/step - loss: 8.8614e-04 - val_loss: 0.1872
# Epoch 46/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.1559
# Epoch 47/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.0870
# Epoch 48/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.1777
# Epoch 49/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.1012
# Epoch 50/100
# 31/31 [==============================] - 0s 11ms/step - loss: 8.9696e-04 - val_loss: 0.1139
# Epoch 51/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.1238
# Epoch 52/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.1300
# Epoch 53/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0535
# Epoch 54/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.1083
# Epoch 55/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.1277
# Epoch 56/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0768
# Epoch 57/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.1115
# Epoch 58/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0755
# Epoch 59/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0970
# Epoch 60/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0794
# Epoch 61/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0887
# Epoch 62/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0582
# Epoch 63/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0593
# Epoch 64/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0740
# Epoch 65/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.1378
# Epoch 66/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0011 - val_loss: 0.1311
# Epoch 67/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0967
# Epoch 68/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 0.1379
# Epoch 69/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1195
# Epoch 70/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.1091
# Epoch 71/100
# 31/31 [==============================] - 0s 11ms/step - loss: 9.7820e-04 - val_loss: 0.0835
# Epoch 72/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0586
# Epoch 73/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0627
# Epoch 74/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0010 - val_loss: 0.0916
# Epoch 75/100
# 31/31 [==============================] - 0s 11ms/step - loss: 9.8982e-04 - val_loss: 0.0542
# Epoch 76/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.1050
# Epoch 77/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0014 - val_loss: 0.0856
# Epoch 78/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 0.0744
# Epoch 79/100
# 31/31 [==============================] - 0s 12ms/step - loss: 8.9869e-04 - val_loss: 0.0839
# Epoch 80/100
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0013 - val_loss: 0.0613
# Epoch 81/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0012 - val_loss: 0.0858
# Epoch 82/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 0.1638
# Epoch 83/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.1045
# Epoch 84/100
# 31/31 [==============================] - 0s 12ms/step - loss: 9.8457e-04 - val_loss: 0.1037
# Epoch 85/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 0.1142
# Epoch 86/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0919
# Epoch 87/100
# 31/31 [==============================] - 0s 12ms/step - loss: 8.0768e-04 - val_loss: 0.1035
# Epoch 88/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.0890
# Epoch 89/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0868
# Epoch 90/100
# 31/31 [==============================] - 0s 12ms/step - loss: 9.3049e-04 - val_loss: 0.0789
# Epoch 91/100
# 31/31 [==============================] - 0s 12ms/step - loss: 9.6950e-04 - val_loss: 0.0647
# Epoch 92/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 0.0726
# Epoch 93/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.0936
# Epoch 94/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.0833
# Epoch 95/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1114
# Epoch 96/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0010 - val_loss: 0.0539
# Epoch 97/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0013 - val_loss: 0.1066
# Epoch 98/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0011 - val_loss: 0.1289
# Epoch 99/100
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0887
# Epoch 100/100
# 31/31 [==============================] - 0s 12ms/step - loss: 9.9079e-04 - val_loss: 0.1595

# %%
plt.plot(range(1, len(history.history['loss']) + 1), history.history['loss'],label="Training loss")
plt.plot(range(1, len(history.history['val_loss']) + 1), history.history['val_loss'],label="Validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
target_scaler = MinMaxScaler()
target_scaler.fit(train_df[['Close']])
#Get the models predicted price values
predictions = model.predict(x_val)
predictions = target_scaler.inverse_transform(predictions)
valid=val_df[15:][['Close']].copy()
valid['Predictions'] = predictions
#get the root mean squared error (RMSE)
rmse = np.sqrt(np.mean(valid['Predictions'] - valid['Close']) ** 2)

print("RMSE:",rmse)
print("Accuracy:",accuracy_forecast(valid['Close'], valid['Predictions']))
# Out:
# RMSE: 1.5654053198639557
# Accuracy: 0.4682080924855491

# %%
#visualize
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Val','Predictions'], loc='lower right')
plt.show()

# %%
X_test

# %%
LINK_quote = web.DataReader('LTC-USD', data_source='yahoo', start='2017-09-21', end='2021-03-10')
#create a new dataframe
new_df = LINK_quote.filter(['Close'])
#Get the last 60 day closing price
last_60_days = new_df[-15:].values
#scale the data
last_60_days_scale = scaler.transform(last_60_days)
#create an empty list
X_test = []
X_test.append(last_60_days_scale)
#convert the x_test to np.array
X_test = np.array(X_test)
#reshape
X_test = np.reshape(X_test, ((X_test.shape[0], X_test.shape[1], 1)))
#get predicted price
pred_price = model.predict(X_test)
#undo scaling
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[202.13531]]

# %%
LINK_quote2 = web.DataReader('LTC-USD', data_source='yahoo', start='2021-03-11', end='2021-03-11')
print(LINK_quote2)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-03-11  203.167831  191.536835  200.449753  201.250336  4823154653
# 2021-03-12  223.614975  198.953842  201.273666  220.829407  8079722567
#
#              Adj Close
# Date
# 2021-03-11  201.250336
# 2021-03-12  220.829407

# %% [markdown]
# ## Multiple input with normal features

# %%
df
# Out:
#                  High        Low       Open      Close        Volume  \
# date
# 2017-09-21   0.207892   0.155292   0.189132   0.169680  2.126270e+06
# 2017-09-22   0.181675   0.139869   0.169826   0.150503  1.423220e+06
# 2017-09-23   0.157440   0.126297   0.149562   0.131129  1.186670e+06
# 2017-09-24   0.190250   0.130275   0.131110   0.170278  1.025740e+06
# 2017-09-25   0.182637   0.158580   0.170636   0.182198  1.021370e+06
# ...               ...        ...        ...        ...           ...
# 2021-02-23  31.549831  21.198072  31.522873  25.800343  5.101236e+09
# 2021-02-24  29.178788  24.645512  25.827651  28.086719  3.087990e+09
# 2021-02-25  28.556830  24.595960  28.073373  24.668047  2.016769e+09
# 2021-02-26  26.948970  23.761681  24.734231  25.187313  1.705493e+11
# 2021-02-27  27.390610  24.906771  25.197746  26.235097  1.874411e+09
#
#                Marketcap
# date
# 2017-09-21  5.938800e+07
# 2017-09-22  5.267605e+07
# 2017-09-23  4.589515e+07
# 2017-09-24  5.959730e+07
# 2017-09-25  6.376930e+07
# ...                  ...
# 2021-02-23  1.053969e+10
# 2021-02-24  1.147369e+10
# 2021-02-25  1.007713e+10
# 2021-02-26  1.032704e+10
# 2021-02-27  1.075664e+10
#
# [1256 rows x 6 columns]

# %%
scaled_train_df, scaler  = scale_func(train_df) 
scaled_val_df = pd.DataFrame(scaler.transform(val_df), index=val_df.index,columns=val_df.columns)
scaled_test_df = pd.DataFrame(scaler.transform(test_df), index=test_df.index,columns=test_df.columns)

# %%
def multiinput_generator(df, target, window):
    feature_cols = df.columns  
    x_train = []
    y_train = []
    for i in range(window, len(df)):
        x_train.append(df.iloc[i-window:i,:])
        y_train.append(df.iloc[i,:][target])
    #convert x_train and y_train to numpy arrays
    x_train, y_train = np.array(x_train), np.array(y_train)
    return x_train,y_train

x_train, y_train = multiinput_generator(scaled_train_df, "Close", 5)
x_val, y_val = multiinput_generator(scaled_val_df, "Close", 5)
x_test, y_test = multiinput_generator(scaled_test_df, "Close", 5)
#coin_history, x_cols = create_history_frames(coin_dataframes)

# %%
#build the lstm model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],x_train.shape[2])))
model.add(LSTM(50, return_sequences=False, dropout=0.2, recurrent_dropout=0.4))
model.add(Dense(1))
model.add(Activation('linear'))
#compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train the model
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), shuffle=True, batch_size=16, epochs=100)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 4s 12ms/step - loss: 0.0335 - val_loss: 0.7068
# Epoch 2/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0032 - val_loss: 0.6835
# Epoch 3/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.8131
# Epoch 4/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.8642
# Epoch 5/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0024 - val_loss: 0.6519
# Epoch 6/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.6281
# Epoch 7/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.5796
# Epoch 8/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.6580
# Epoch 9/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.6204
# Epoch 10/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.6467
# Epoch 11/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.6058
# Epoch 12/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.6080
# Epoch 13/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.5095
# Epoch 14/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.6273
# Epoch 15/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.4462
# Epoch 16/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.7251
# Epoch 17/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.7973
# Epoch 18/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.4943
# Epoch 19/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.7580
# Epoch 20/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.4650
# Epoch 21/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.5464
# Epoch 22/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.9752e-04 - val_loss: 0.4505
# Epoch 23/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.5712
# Epoch 24/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.6792
# Epoch 25/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.5620
# Epoch 26/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.6543
# Epoch 27/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.4213
# Epoch 28/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.5907
# Epoch 29/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.3422
# Epoch 30/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.8308e-04 - val_loss: 0.2484
# Epoch 31/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.4078
# Epoch 32/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.3011
# Epoch 33/100
# 63/63 [==============================] - 1s 17ms/step - loss: 0.0012 - val_loss: 0.4823
# Epoch 34/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.2606e-04 - val_loss: 0.4666
# Epoch 35/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.4670
# Epoch 36/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.4949
# Epoch 37/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.6306
# Epoch 38/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.3712
# Epoch 39/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.3784e-04 - val_loss: 0.3825
# Epoch 40/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.6051e-04 - val_loss: 0.3613
# Epoch 41/100
# 63/63 [==============================] - 0s 4ms/step - loss: 8.4402e-04 - val_loss: 0.5664
# Epoch 42/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.4503
# Epoch 43/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.3441
# Epoch 44/100
# 63/63 [==============================] - 0s 4ms/step - loss: 8.2822e-04 - val_loss: 0.4212
# Epoch 45/100
# 63/63 [==============================] - 0s 4ms/step - loss: 8.5019e-04 - val_loss: 0.3252
# Epoch 46/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.1374e-04 - val_loss: 0.5950
# Epoch 47/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.9876e-04 - val_loss: 0.5864
# Epoch 48/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.3390
# Epoch 49/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.3245e-04 - val_loss: 0.5229
# Epoch 50/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.4693
# Epoch 51/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.4217
# Epoch 52/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.8271e-04 - val_loss: 0.4764
# Epoch 53/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.3059
# Epoch 54/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.4975
# Epoch 55/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.6922e-04 - val_loss: 0.4108
# Epoch 56/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.4313
# Epoch 57/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.5045
# Epoch 58/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.4147
# Epoch 59/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.4022e-04 - val_loss: 0.3901
# Epoch 60/100
# 63/63 [==============================] - 0s 5ms/step - loss: 9.4648e-04 - val_loss: 0.4014
# Epoch 61/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.1905e-04 - val_loss: 0.3104
# Epoch 62/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.4932
# Epoch 63/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.6287e-04 - val_loss: 0.4623
# Epoch 64/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.0268e-04 - val_loss: 0.2897
# Epoch 65/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.6128e-04 - val_loss: 0.3611
# Epoch 66/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.3916
# Epoch 67/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.5912e-04 - val_loss: 0.4191
# Epoch 68/100
# 63/63 [==============================] - 0s 4ms/step - loss: 6.7801e-04 - val_loss: 0.4075
# Epoch 69/100
# 63/63 [==============================] - 0s 5ms/step - loss: 7.5614e-04 - val_loss: 0.4065
# Epoch 70/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.3431
# Epoch 71/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.5014e-04 - val_loss: 0.3881
# Epoch 72/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.2142e-04 - val_loss: 0.4092
# Epoch 73/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.3797e-04 - val_loss: 0.4175
# Epoch 74/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.3566
# Epoch 75/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.2620e-04 - val_loss: 0.3411
# Epoch 76/100
# 63/63 [==============================] - 0s 5ms/step - loss: 9.5082e-04 - val_loss: 0.4336
# Epoch 77/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.3057
# Epoch 78/100
# 63/63 [==============================] - 0s 4ms/step - loss: 8.3865e-04 - val_loss: 0.3483
# Epoch 79/100
# 63/63 [==============================] - 0s 5ms/step - loss: 7.2162e-04 - val_loss: 0.4499
# Epoch 80/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.0608e-04 - val_loss: 0.3289
# Epoch 81/100
# 63/63 [==============================] - 0s 5ms/step - loss: 9.2391e-04 - val_loss: 0.3329
# Epoch 82/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.0213e-04 - val_loss: 0.3329
# Epoch 83/100
# 63/63 [==============================] - 0s 5ms/step - loss: 9.7746e-04 - val_loss: 0.3608
# Epoch 84/100
# 63/63 [==============================] - 0s 4ms/step - loss: 6.6172e-04 - val_loss: 0.3646
# Epoch 85/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.3734
# Epoch 86/100
# 63/63 [==============================] - 0s 4ms/step - loss: 8.8582e-04 - val_loss: 0.4119
# Epoch 87/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.3381
# Epoch 88/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.3883
# Epoch 89/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.2093e-04 - val_loss: 0.4417
# Epoch 90/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.3538
# Epoch 91/100
# 63/63 [==============================] - 0s 4ms/step - loss: 6.7601e-04 - val_loss: 0.4125
# Epoch 92/100
# 63/63 [==============================] - 0s 4ms/step - loss: 9.8384e-04 - val_loss: 0.4202
# Epoch 93/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.4249
# Epoch 94/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.4111
# Epoch 95/100
# 63/63 [==============================] - 0s 4ms/step - loss: 6.6899e-04 - val_loss: 0.4678
# Epoch 96/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.7260e-04 - val_loss: 0.4728
# Epoch 97/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.8608e-04 - val_loss: 0.4406
# Epoch 98/100
# 63/63 [==============================] - 0s 4ms/step - loss: 7.6280e-04 - val_loss: 0.5327
# Epoch 99/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.8735e-04 - val_loss: 0.4686
# Epoch 100/100
# 63/63 [==============================] - 0s 5ms/step - loss: 8.0884e-04 - val_loss: 0.5699

# %%
plt.plot(range(1, len(history.history['loss']) + 1), history.history['loss'],label="Training loss")
plt.plot(range(1, len(history.history['val_loss']) + 1), history.history['val_loss'],label="Validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
target_scaler = MinMaxScaler()
target_scaler.fit(train_df[['Close']])
#Get the models predicted price values
predictions = model.predict(x_val)
predictions = target_scaler.inverse_transform(predictions)

# %%
#plot the data
valid = val_df[['Close']][5:].copy()
valid['Predictions'] = predictions
#visualize
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Val','Predictions'], loc='lower right')
plt.show()

# %%
mean_absolute_error(valid['Close'], valid['Predictions'])
# Out:
# 2.9672082567582625

# %% [markdown]
# ### Test data

# %%
#Get the models predicted price values
predictions = model.predict(x_test)
predictions = target_scaler.inverse_transform(predictions)

# %%
#plot the data
valid = test_df[['Close']][5:].copy()
valid['Predictions'] = predictions
#visualize
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Test','Predictions'], loc='lower right')
plt.show()

# %%
mean_absolute_error(valid['Close'], valid['Predictions'])
# Out:
# 8.67079165147202

# %% [markdown]
# # Bidirectional

# %%
#build the lstm model
model = Sequential()
model.add(Bidirectional(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],x_train.shape[2]))))
model.add(Bidirectional(LSTM(50, return_sequences=False, dropout=0.2, recurrent_dropout=0.4)))
model.add(Dense(1))
model.add(Activation('linear'))
#compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train the model
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), shuffle=False,batch_size=16, epochs=100)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 34s 72ms/step - loss: 0.5155 - val_loss: 0.0671
# Epoch 2/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1776 - val_loss: 0.0054
# Epoch 3/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.2099 - val_loss: 0.0641
# Epoch 4/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1193 - val_loss: 0.0052
# Epoch 5/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0681 - val_loss: 0.0064
# Epoch 6/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0599 - val_loss: 0.0088
# Epoch 7/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0811 - val_loss: 0.0121
# Epoch 8/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0656 - val_loss: 0.0077
# Epoch 9/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0563 - val_loss: 0.0083
# Epoch 10/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0500 - val_loss: 0.0051
# Epoch 11/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.1523 - val_loss: 0.0361
# Epoch 12/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.1045 - val_loss: 0.0083
# Epoch 13/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0670 - val_loss: 0.0202
# Epoch 14/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0915 - val_loss: 0.0221
# Epoch 15/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0834 - val_loss: 0.0108
# Epoch 16/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.1114 - val_loss: 0.0361
# Epoch 17/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.2213 - val_loss: 0.0271
# Epoch 18/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0720 - val_loss: 0.0583
# Epoch 19/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0843 - val_loss: 0.0048
# Epoch 20/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0458 - val_loss: 0.0083
# Epoch 21/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0459 - val_loss: 0.0045
# Epoch 22/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0417 - val_loss: 0.0065
# Epoch 23/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0383 - val_loss: 0.0047
# Epoch 24/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0406 - val_loss: 0.0071
# Epoch 25/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0432 - val_loss: 0.0056
# Epoch 26/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0423 - val_loss: 0.0107
# Epoch 27/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0434 - val_loss: 0.0114
# Epoch 28/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0829 - val_loss: 0.0056
# Epoch 29/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0451 - val_loss: 0.0308
# Epoch 30/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0723 - val_loss: 0.0200
# Epoch 31/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.1636 - val_loss: 0.0101
# Epoch 32/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0495 - val_loss: 0.0569
# Epoch 33/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0618 - val_loss: 0.0064
# Epoch 34/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0670 - val_loss: 0.0048
# Epoch 35/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0414 - val_loss: 0.0156
# Epoch 36/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0407 - val_loss: 0.0078
# Epoch 37/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0670 - val_loss: 0.0057
# Epoch 38/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0546 - val_loss: 0.0242
# Epoch 39/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0622 - val_loss: 0.0056
# Epoch 40/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0471 - val_loss: 0.0154
# Epoch 41/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0588 - val_loss: 0.0145
# Epoch 42/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0806 - val_loss: 0.0054
# Epoch 43/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0389 - val_loss: 0.0276
# Epoch 44/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0450 - val_loss: 0.0078
# Epoch 45/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0498 - val_loss: 0.0113
# Epoch 46/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0454 - val_loss: 0.0179
# Epoch 47/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0465 - val_loss: 0.0076
# Epoch 48/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0430 - val_loss: 0.0127
# Epoch 49/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0483 - val_loss: 0.0166
# Epoch 50/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0598 - val_loss: 0.0067
# Epoch 51/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0383 - val_loss: 0.0190
# Epoch 52/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0634 - val_loss: 0.0197
# Epoch 53/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0986 - val_loss: 0.0053
# Epoch 54/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0380 - val_loss: 0.0325
# Epoch 55/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0503 - val_loss: 0.0130
# Epoch 56/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0729 - val_loss: 0.0056
# Epoch 57/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0381 - val_loss: 0.0237
# Epoch 58/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0418 - val_loss: 0.0076
# Epoch 59/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0424 - val_loss: 0.0109
# Epoch 60/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0489 - val_loss: 0.0156
# Epoch 61/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0544 - val_loss: 0.0070
# Epoch 62/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0371 - val_loss: 0.0094
# Epoch 63/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0502 - val_loss: 0.0206
# Epoch 64/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0848 - val_loss: 0.0047
# Epoch 65/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0364 - val_loss: 0.0242
# Epoch 66/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0443 - val_loss: 0.0139
# Epoch 67/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0718 - val_loss: 0.0053
# Epoch 68/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0367 - val_loss: 0.0250
# Epoch 69/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0460 - val_loss: 0.0118
# Epoch 70/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0617 - val_loss: 0.0055
# Epoch 71/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0456 - val_loss: 0.0234
# Epoch 72/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0551 - val_loss: 0.0064
# Epoch 73/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0411 - val_loss: 0.0121
# Epoch 74/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0555 - val_loss: 0.0176
# Epoch 75/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0770 - val_loss: 0.0041
# Epoch 76/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0324 - val_loss: 0.0214
# Epoch 77/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0414 - val_loss: 0.0122
# Epoch 78/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0616 - val_loss: 0.0042
# Epoch 79/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0402 - val_loss: 0.0204
# Epoch 80/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0470 - val_loss: 0.0058
# Epoch 81/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0324 - val_loss: 0.0095
# Epoch 82/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0397 - val_loss: 0.0131
# Epoch 83/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0540 - val_loss: 0.0044
# Epoch 84/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0320 - val_loss: 0.0137
# Epoch 85/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0356 - val_loss: 0.0113
# Epoch 86/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0498 - val_loss: 0.0042
# Epoch 87/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0421 - val_loss: 0.0213
# Epoch 88/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0545 - val_loss: 0.0049
# Epoch 89/100
# 60/60 [==============================] - 1s 15ms/step - loss: 0.0326 - val_loss: 0.0126
# Epoch 90/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0418 - val_loss: 0.0134
# Epoch 91/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0675 - val_loss: 0.0043
# Epoch 92/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0363 - val_loss: 0.0166
# Epoch 93/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0415 - val_loss: 0.0159
# Epoch 94/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0675 - val_loss: 0.0042
# Epoch 95/100
# 60/60 [==============================] - 1s 13ms/step - loss: 0.0419 - val_loss: 0.0218
# Epoch 96/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0493 - val_loss: 0.0084
# Epoch 97/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0391 - val_loss: 0.0054
# Epoch 98/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0431 - val_loss: 0.0198
# Epoch 99/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0677 - val_loss: 0.0045
# Epoch 100/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0318 - val_loss: 0.0094

# %%
plt.plot(range(1, len(history.history['loss']) + 1), history.history['loss'],label="Training loss")
plt.plot(range(1, len(history.history['val_loss']) + 1), history.history['val_loss'],label="Validation loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
target_scaler = StandardScaler()
target_scaler.fit(train_df[['Close']])
#Get the models predicted price values
predictions = model.predict(x_val)
predictions = target_scaler.inverse_transform(predictions)

# %%
#plot the data
valid = val_df[['Close']][5:].copy()
valid['Predictions'] = predictions
#visualize
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Val','Predictions'], loc='lower right')
plt.show()

# %%
mean_absolute_error(valid['Close'], valid['Predictions'])
# Out:
# 4.050404185172386

# %% [markdown]
# ### Test data

# %%
#Get the models predicted price values
predictions = model.predict(x_test)
predictions = target_scaler.inverse_transform(predictions)

# %%
#plot the data
valid = test_df[['Close']][5:].copy()
valid['Predictions'] = predictions
#visualize
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Test','Predictions'], loc='lower right')
plt.show()

# %%
mean_absolute_error(valid['Close'], valid['Predictions'])
# Out:
# 8.477366795583865
